# %%
import os.path as path
from os import path
import pickle
import torch

import szx82.models.bert.pre.train as TRAIN
import szx82.models.bert.pre.model as MODEL

# %%
DATA_STORE = 'G:/My Drive/workplaces/szx81/EURUSD/data_store'
DATA_NAME = 'tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;'

DATA_FILE = path.join(
        DATA_STORE,
        'dev_tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;.pkl')

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

torch.autograd.set_detect_anomaly(False) 

def trainer():
    training_shell = TRAIN.Train(
        file_name='bert',
        data_store=DATA_STORE,
        data=None,
        model=MODEL.MODEL,
    )

    def restore_project_training(project_file):
        project_shell = None
        try:
            path.exists(project_file)
            with open(project_file, 'rb') as f:
                project_shell = pickle.load(f)
        except Exception as ex:
            print(f'ERROR!\n{str(ex)}')
        if project_shell is not None:
            project_shell.train()

    # # RESTORE
    # restore_project_training(
    #      r'C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;\BERT_PRE_bert_rv_dev\BERT_PRE_bert_rv_dev.pkl')

    # # ##### PROJECT
    # training_shell.data = TRAIN.data(DATA_FILE, DEVICE)
    # # vocab:  RY9oRdHDGk7rFWlsW2RnCDqvJtg=
    # training_shell.batch_size = 256
    # training_shell.train(DEVICE, name_prep='bs256')
    # # loss trn,val:0.37,0.44 best: 0.62

    # ##### testing DEVELOPMENT
    training_shell.data = TRAIN.data(DATA_FILE, DEVICE)
    training_shell.batch_size = 64
    training_shell.stop_thd=0.2
    training_shell.init(DEVICE, name_prep='dev', force=True)
    training_shell.train()
    

    # ##### testing training CONTINUATION
    # training_shell.model_config_or_path = r'C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;\BERT_PRE_bert_rv\BERT_PRE_bert_rv_bst_.pt'
    # training_shell.train(DEVICE, name_prep='cont')

    '''DEFAULTS:
    '''
trainer()
# Out:
# train data size: 5619
# validation data size: 1874
# test data size: 2497
# vocab hash: RY9oRdHDGk7rFWlsW2RnCDqvJtg=
# train.py 1153;  id(type(self.config)): 2408545402000
#
# project dir: G:\My Drive\workplaces\szx81\EURUSD\data_store\tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;\BERT_PRE_bert_dev
# project name: BERT_PRE_bert_dev
#
#  training; loss trn,val:0.51,0.50; best:0.37; train:nsp,mlm:-0.02,0.38; val.:nsp,mlm:-0.02,0.38; ep:8; batch:29/87;
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 56
#      50     # ##### testing training CONTINUATION
#      51     # training_shell.model_config_or_path = r'C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;\BERT_PRE_bert_rv\BERT_PRE_bert_rv_bst_.pt'
#      52     # training_shell.train(DEVICE, name_prep='cont')
#      54     '''DEFAULTS:
#      55     '''
# ---> 56 trainer()
#
# Cell In[2], line 47, in trainer()
#      45 training_shell.stop_thd=0.2
#      46 training_shell.init(DEVICE, name_prep='dev', force=True)
# ---> 47 training_shell.train()
#      50 # ##### testing training CONTINUATION
#      51 # training_shell.model_config_or_path = r'C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;\BERT_PRE_bert_rv\BERT_PRE_bert_rv_bst_.pt'
#      52 # training_shell.train(DEVICE, name_prep='cont')
#      54 '''DEFAULTS:
#      55 '''
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\pre\train.py:187, in Train.train(self)
#     186 def train(self):
# --> 187     self.project_shell.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\project_shell.py:90, in ProjectShell.train(self)
#      88 def train(self):
#      89     if self.ok_run:
# ---> 90         self.ms.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\model_shell.py:132, in ModelShell.train(self)
#     129     train_running_loss += loss.item()
#     131     if not first_epoch:
# --> 132         loss.mean().backward()
#     133         self.optimizer.step()
#     135 train_loss = train_running_loss / (idx + 1) \
#     136                                 / self.train_dataloader.batch_size
#
# File c:\Python\Python310\lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Python\Python310\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Python\Python310\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:
