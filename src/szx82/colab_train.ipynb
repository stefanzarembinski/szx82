# %%
import os.path as path
from os import path
import torch

from szx82.models.bert.train import Train as TRAIN
import szx82.models.bert.pre.model as PRE
from szx82.models.bert.re_train import data, ReTrain as RE_TRAIN
import szx82.models.bert.cls.model as CLS

# %%
DATA_STORE = r'C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store'
DATA_STORE_G = 'G:/My Drive/workplaces/szx81/EURUSD/data_store'
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
def trainer():
    training_shell = TRAIN(
        data_store=DATA_STORE,
        data=None,
        model=None,
    )

    # # ##### PROJECT
    training_shell.model = PRE.MODEL
    training_shell.data = data(path.join(
            DATA_STORE,'data_4-8-8_tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;style-narrow;_pre.pkl'), DEVICE, scale=0.03) # scale!!!!!!!!! 
    training_shell.batch_size = 256
    training_shell.hidden_size = 384 # defaults to 768
    training_shell.intermediate_size = 1536 # 4 * hidden_size? # defaults to 3072
    training_shell.num_hidden_layers = 10 # defaults to 12
    training_shell.num_attention_heads = 4 # defaults to 12
    training_shell.dropuot = 0.1 # default is 0.1
    training_shell.stop_thd=0.1
    training_shell.init(DEVICE, name_prep='pre', force=False)
    training_shell.train()

trainer()
# Out:
# train data size: 5400
# validation data size: 1350
# test data size: 2252
# vocab hash: 36e8e80b5f37218c
#
# project dir: C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\4-8-8_tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;style-narrow;\BERT_PRE_pre
# project name: BERT_PRE_pre
#
#  validation; loss trn,val:0.76,1.00; best:0.57; train:nsp,mlm:0.51,0.21; val.:nsp,mlm:0.55,0.02; ep:1; batch:10/11;       Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\stefa\AppData\Local\Temp\ipykernel_21500\3005755295.py", line 22, in <module>
#     trainer()
#   File "C:\Users\stefa\AppData\Local\Temp\ipykernel_21500\3005755295.py", line 20, in trainer
#     training_shell.train()
#   File "G:\My Drive\workplaces\szx82\src\szx82\models\bert\re_train.py", line 146, in train
#     self.project_shell.train()
#   File "G:\My Drive\workplaces\szx82\src\szx82\models\project_shell.py", line 92, in train
#     self.ms.train()
#   File "G:\My Drive\workplaces\szx82\src\szx82\models\model_shell.py", line 181, in train
#     best=True,
#   File "G:\My Drive\workplaces\szx82\src\szx82\models\project_shell.py", line 135, in save_model
#     self.ms.save_model(file_path)
#   File "G:\My Drive\workplaces\szx82\src\szx82\models\model_shell.py", line 195, in save_model
#   File "G:\My Drive\workplaces\szx82\src\szx82\models\model_shell.py", line 195, in save_model
#   File "_pydevd_bundle/pydevd_cython.pyx", line 1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__
#   File "_pydevd_bundle/pydevd_cython.pyx", line 701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch
#   File "_pydevd_bundle/pydevd_cython.pyx", line 1152, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch
#   File "_pydevd_bundle/pydevd_cython.pyx", line 1135, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch
#   File "_pydevd_bundle/pydevd_cython.pyx", line 312, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\debugpy\_vendored\pydevd\pydevd.py", line 2070, in do_wait_suspend
#     keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\debugpy\_vendored\pydevd\pydevd.py", line 2106, in _do_wait_suspend
#     time.sleep(0.01)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1172, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 1087, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 969, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#   File "C:\Users\stefa\AppData\Roaming\Python\Python310\site-packages\executing\executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
def trainer():
    training_shell = TRAIN(
        data_store=DATA_STORE,
        data=None,
        model=None,
    )

    # # ##### PROJECT
    training_shell. model = PRE.MODEL
    training_shell.data = data(path.join(
            DATA_STORE,'data_tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;_snd.pkl'), DEVICE)
    training_shell.batch_size = 256
    training_shell.hidden_size = 384 # defaults to 768
    training_shell.intermediate_size = 1536 # 4 * hidden_size? # defaults to 3072
    training_shell.num_hidden_layers = 6 # defaults to 12
    training_shell.num_attention_heads = 6 # defaults to 12
    training_shell.dropuot = 0.3 # default is 0.1
    training_shell.stop_thd=0.2
    training_shell.init(DEVICE, name_prep='half', force=True)
    training_shell.train()

trainer()
# Out:
# train data size: 179994
# validation data size: 44999
# test data size: 74997
# vocab hash: e10518ec19978398
#
# project dir: C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;\BERT_PRE_half
# project name: BERT_PRE_half
#
#  training; wait... ep:0; batch:120/704;
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 22
#      19     training_shell.init(DEVICE, name_prep='half', force=True)
#      20     training_shell.train()
# ---> 22 trainer()
#
# Cell In[5], line 20, in trainer()
#      18 training_shell.stop_thd=0.2
#      19 training_shell.init(DEVICE, name_prep='half', force=True)
# ---> 20 training_shell.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\re_train.py:146, in ReTrain.train(self)
#     145 def train(self):
# --> 146     self.project_shell.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\project_shell.py:92, in ProjectShell.train(self)
#      90 def train(self):
#      91     if self.ok_run:
# ---> 92         self.ms.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\model_shell.py:134, in ModelShell.train(self)
#     131 print_progress('training', epochs, idx, self.train_dataloader)
#     133 self.optimizer.zero_grad()
# --> 134 loss = self.model_env(batch)
#     135 train_current.append(self.model_env.current)
#     136 train_running_loss += loss.item()
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\pre\model.py:63, in MODEL.forward(self, batch)
#      62 def forward(self, batch):
# ---> 63     model_out = self.model(
#      64             output_hidden_states=True,
#      65             return_dict=True,
#      66             **batch['input']
#      67         )
#      68     prediction_logits = model_out.prediction_logits
#      69     seq_relationship_logits = model_out.seq_relationship_logits
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:1248, in BertForPreTraining.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, next_sentence_label, output_attentions, output_hidden_states, return_dict)
#    1214 r"""
#    1215     labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1216         Labels for computing the masked language modeling loss. Indices should be in `[-100, 0, ...,
#    (...)
#    1244 ```
#    1245 """
#    1246 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1248 outputs = self.bert(
#    1249     input_ids,
#    1250     attention_mask=attention_mask,
#    1251     token_type_ids=token_type_ids,
#    1252     position_ids=position_ids,
#    1253     head_mask=head_mask,
#    1254     inputs_embeds=inputs_embeds,
#    1255     output_attentions=output_attentions,
#    1256     output_hidden_states=output_hidden_states,
#    1257     return_dict=return_dict,
#    1258 )
#    1260 sequence_output, pooled_output = outputs[:2]
#    1261 prediction_scores, seq_relationship_score = self.cls(sequence_output, pooled_output)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:1144, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1137 # Prepare head mask if needed
#    1138 # 1.0 in head_mask indicate we keep the head
#    1139 # attention_probs has shape bsz x n_heads x N x N
#    1140 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1141 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1142 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1144 encoder_outputs = self.encoder(
#    1145     embedding_output,
#    1146     attention_mask=extended_attention_mask,
#    1147     head_mask=head_mask,
#    1148     encoder_hidden_states=encoder_hidden_states,
#    1149     encoder_attention_mask=encoder_extended_attention_mask,
#    1150     past_key_values=past_key_values,
#    1151     use_cache=use_cache,
#    1152     output_attentions=output_attentions,
#    1153     output_hidden_states=output_hidden_states,
#    1154     return_dict=return_dict,
#    1155 )
#    1156 sequence_output = encoder_outputs[0]
#    1157 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:695, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     684     layer_outputs = self._gradient_checkpointing_func(
#     685         layer_module.__call__,
#     686         hidden_states,
#    (...)
#     692         output_attentions,
#     693     )
#     694 else:
# --> 695     layer_outputs = layer_module(
#     696         hidden_states,
#     697         attention_mask,
#     698         layer_head_mask,
#     699         encoder_hidden_states,
#     700         encoder_attention_mask,
#     701         past_key_value,
#     702         output_attentions,
#     703     )
#     705 hidden_states = layer_outputs[0]
#     706 if use_cache:
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:585, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     573 def forward(
#     574     self,
#     575     hidden_states: torch.Tensor,
#    (...)
#     582 ) -> Tuple[torch.Tensor]:
#     583     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     584     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 585     self_attention_outputs = self.attention(
#     586         hidden_states,
#     587         attention_mask,
#     588         head_mask,
#     589         output_attentions=output_attentions,
#     590         past_key_value=self_attn_past_key_value,
#     591     )
#     592     attention_output = self_attention_outputs[0]
#     594     # if decoder, the last output is tuple of self-attn cache
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:515, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     505 def forward(
#     506     self,
#     507     hidden_states: torch.Tensor,
#    (...)
#     513     output_attentions: Optional[bool] = False,
#     514 ) -> Tuple[torch.Tensor]:
# --> 515     self_outputs = self.self(
#     516         hidden_states,
#     517         attention_mask,
#     518         head_mask,
#     519         encoder_hidden_states,
#     520         encoder_attention_mask,
#     521         past_key_value,
#     522         output_attentions,
#     523     )
#     524     attention_output = self.output(self_outputs[0], hidden_states)
#     525     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:409, in BertSdpaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     407 else:
#     408     key_layer = self.transpose_for_scores(self.key(current_states))
# --> 409     value_layer = self.transpose_for_scores(self.value(current_states))
#     410     if past_key_value is not None and not is_cross_attention:
#     411         key_layer = torch.cat([past_key_value[0], key_layer], dim=2)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
def trainer():
    training_shell = RE_TRAIN(
        data_store=DATA_STORE,
        data=None,
        model=None,
    )
    training_shell.model = CLS.MODEL
    training_shell.data = data(path.join(
            DATA_STORE,
            'data_tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;_cls.pkl'), DEVICE)
    training_shell.pretrained_path = path.join(
        DATA_STORE_G, 
        path.join(
            'tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;/BERT_PRE_bert_half', 'BERT_PRE_bert_half_bst_.pt'))
    training_shell.batch_size = 512
    training_shell.stop_thd=0.2
    training_shell.init(DEVICE, name_prep='h512', force=True)
    training_shell.train()
    
trainer()
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at G:/My Drive/workplaces/szx81/EURUSD/data_store\tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;/BERT_PRE_bert_half\BERT_PRE_bert_half_bst_.pt and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# train data size: 112494
# validation data size: 37499
# test data size: 49997
# vocab hash: e10518ec19978398
#
# project dir: C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;\BERT_CLS_bert_h512
# project name: BERT_CLS_bert_h512
#
#  validation; wait... ep:1; batch:280/293;
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 21
#      18     training_shell.init(DEVICE, name_prep='h512', force=True)
#      19     training_shell.train()
# ---> 21 trainer()
#
# Cell In[5], line 19, in trainer()
#      17 training_shell.stop_thd=0.2
#      18 training_shell.init(DEVICE, name_prep='h512', force=True)
# ---> 19 training_shell.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\re_train.py:130, in ReTrain.train(self)
#     129 def train(self):
# --> 130     self.project_shell.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\project_shell.py:90, in ProjectShell.train(self)
#      88 def train(self):
#      89     if self.ok_run:
# ---> 90         self.ms.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\model_shell.py:161, in ModelShell.train(self)
#     158 for idx, batch in enumerate(self.val_dataloader):
#     159     print_progress('validation', epochs, idx, self.val_dataloader)
# --> 161     loss = self.model_env(batch)
#     162     val_current.append(self.model_env.current)
#     163     val_running_loss += loss.item()
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\cls\model.py:28, in MODEL.forward(self, batch)
#      27 def forward(self, batch):
# ---> 28     model_out = self.model(
#      29             output_hidden_states=True,
#      30             return_dict=True,
#      31             **batch['input']
#      32         )
#      34     logits = model_out.logits
#      35     loss = model_out.loss
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:1675, in BertForSequenceClassification.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict)
#    1667 r"""
#    1668 labels (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1669     Labels for computing the sequence classification/regression loss. Indices should be in `[0, ...,
#    1670     config.num_labels - 1]`. If `config.num_labels == 1` a regression loss is computed (Mean-Square loss), If
#    1671     `config.num_labels > 1` a classification loss is computed (Cross-Entropy).
#    1672 """
#    1673 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1675 outputs = self.bert(
#    1676     input_ids,
#    1677     attention_mask=attention_mask,
#    1678     token_type_ids=token_type_ids,
#    1679     position_ids=position_ids,
#    1680     head_mask=head_mask,
#    1681     inputs_embeds=inputs_embeds,
#    1682     output_attentions=output_attentions,
#    1683     output_hidden_states=output_hidden_states,
#    1684     return_dict=return_dict,
#    1685 )
#    1687 pooled_output = outputs[1]
#    1689 pooled_output = self.dropout(pooled_output)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:1144, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1137 # Prepare head mask if needed
#    1138 # 1.0 in head_mask indicate we keep the head
#    1139 # attention_probs has shape bsz x n_heads x N x N
#    1140 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1141 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1142 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1144 encoder_outputs = self.encoder(
#    1145     embedding_output,
#    1146     attention_mask=extended_attention_mask,
#    1147     head_mask=head_mask,
#    1148     encoder_hidden_states=encoder_hidden_states,
#    1149     encoder_attention_mask=encoder_extended_attention_mask,
#    1150     past_key_values=past_key_values,
#    1151     use_cache=use_cache,
#    1152     output_attentions=output_attentions,
#    1153     output_hidden_states=output_hidden_states,
#    1154     return_dict=return_dict,
#    1155 )
#    1156 sequence_output = encoder_outputs[0]
#    1157 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:695, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     684     layer_outputs = self._gradient_checkpointing_func(
#     685         layer_module.__call__,
#     686         hidden_states,
#    (...)
#     692         output_attentions,
#     693     )
#     694 else:
# --> 695     layer_outputs = layer_module(
#     696         hidden_states,
#     697         attention_mask,
#     698         layer_head_mask,
#     699         encoder_hidden_states,
#     700         encoder_attention_mask,
#     701         past_key_value,
#     702         output_attentions,
#     703     )
#     705 hidden_states = layer_outputs[0]
#     706 if use_cache:
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:585, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     573 def forward(
#     574     self,
#     575     hidden_states: torch.Tensor,
#    (...)
#     582 ) -> Tuple[torch.Tensor]:
#     583     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     584     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 585     self_attention_outputs = self.attention(
#     586         hidden_states,
#     587         attention_mask,
#     588         head_mask,
#     589         output_attentions=output_attentions,
#     590         past_key_value=self_attn_past_key_value,
#     591     )
#     592     attention_output = self_attention_outputs[0]
#     594     # if decoder, the last output is tuple of self-attn cache
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:515, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     505 def forward(
#     506     self,
#     507     hidden_states: torch.Tensor,
#    (...)
#     513     output_attentions: Optional[bool] = False,
#     514 ) -> Tuple[torch.Tensor]:
# --> 515     self_outputs = self.self(
#     516         hidden_states,
#     517         attention_mask,
#     518         head_mask,
#     519         encoder_hidden_states,
#     520         encoder_attention_mask,
#     521         past_key_value,
#     522         output_attentions,
#     523     )
#     524     attention_output = self.output(self_outputs[0], hidden_states)
#     525     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:440, in BertSdpaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     432 # We dispatch to SDPA's Flash Attention or Efficient kernels via this `is_causal` if statement instead of an inline conditional assignment
#     433 # in SDPA to support both torch.compile's dynamic shapes and full graph options. An inline conditional prevents dynamic shapes from compiling.
#     434 # The tgt_len > 1 is necessary to match with AttentionMaskConverter.to_causal_4d that does not create
#     435 # a causal mask in case tgt_len == 1.
#     436 is_causal = (
#     437     True if self.is_decoder and not is_cross_attention and attention_mask is None and tgt_len > 1 else False
#     438 )
# --> 440 attn_output = torch.nn.functional.scaled_dot_product_attention(
#     441     query_layer,
#     442     key_layer,
#     443     value_layer,
#     444     attn_mask=attention_mask,
#     445     dropout_p=self.dropout_prob if self.training else 0.0,
#     446     is_causal=is_causal,
#     447 )
#     449 attn_output = attn_output.transpose(1, 2)
#     450 attn_output = attn_output.reshape(bsz, tgt_len, self.all_head_size)
#
# KeyboardInterrupt:

# %%
def trainer():
    training_shell = RE_TRAIN(
        data_store=DATA_STORE,
        data=None,
        model=None,
    )
    training_shell.model = PRE.MODEL
    training_shell.data = data(path.join(
            DATA_STORE,
            'data_4-8-8_tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;style-narrow;_pre.pkl'), DEVICE, scale=0.3)
    training_shell.pretrained_path = path.join(
        DATA_STORE, 
        '4-8-8_tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;style-narrow;', 'BERT_PRE_pre', 'model_bst_.pt')
    training_shell.batch_size = 128
    training_shell.stop_thd=0.1
    training_shell.init(DEVICE, name_prep='pre', force=False)
    training_shell.train()
    
trainer()
# Out:
# train data size: 54015
# validation data size: 13511
# test data size: 22503
# vocab hash: 36e8e80b5f37218c
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 19
#      16     training_shell.init(DEVICE, name_prep='pre', force=False)
#      17     training_shell.train()
# ---> 19 trainer()
#
# Cell In[8], line 16, in trainer()
#      14 training_shell.batch_size = 128
#      15 training_shell.stop_thd=0.1
# ---> 16 training_shell.init(DEVICE, name_prep='pre', force=False)
#      17 training_shell.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\re_train.py:132, in ReTrain.init(self, device, name_prep, force)
#     131 def init(self, device, name_prep=None, force=False):
# --> 132     self.set_project_shell(device, name_prep)
#     134     config = self.project_shell.ms.model_env.model.config
#     135     mpe = config.max_position_embeddings
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\re_train.py:103, in ReTrain.set_project_shell(self, device, name_prep)
#      95         self.tokenizer_par = self.data['parameters']
#      97         print(f'''
#      98 train data size: {len(train_dataset)}
#      99 validation data size: {len(val_dataset)}
#     100 test data size: {len(self.data['test_data'])}
#     101 vocab hash: {self.tokenizer_par['vocab_hash']}''')
# --> 103         model_shell = ModelShell(
#     104                 train_dataloader=DataLoader(
#     105                                     train_dataset,
#     106                                     batch_size=self.batch_size,
#     107                                     shuffle=True,
#     108                                     pin_memory=False,
#     109                                     drop_last=False,
#     110                                 ),
#     111                 val_dataloader=DataLoader(
#     112                                     val_dataset,
#     113                                     batch_size=128,
#     114                                     shuffle=False,
#     115                                     pin_memory=False,
#     116                                     drop_last=False,
#     117                                 ),
#     118                 ModelClass=self.model,
#     119                 config_or_path=self.config_or_path(),
#     120                 lr=self.lr,
#     121         )
#     123         self.project_shell = ProjectShell(
#     124                 model_shell=model_shell,
#     125                 store_dir=path.join(
#    (...)
#     128                 stop_thd=self.stop_thd
#     129             )
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\model_shell.py:54, in ModelShell.__init__(self, train_dataloader, val_dataloader, ModelClass, config_or_path, lr, weight_decay, betas, warmup_steps, **kwargs)
#      41 def __init__(
#      42     self,
#      43     train_dataloader,
#    (...)
#      51     **kwargs
#      52 ):
#      53     self.label = {'ModelClass': ModelClass}
# ---> 54     self.model_env = ModelClass(
#      55         config_or_path=config_or_path,
#      56         shell=self,
#      57         kwargs=kwargs
#      58     )
#      60     self.train_dataloader = train_dataloader
#      61     self.val_dataloader = val_dataloader
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\pre\model.py:33, in MODEL.__init__(self, config_or_path, shell, **kwargs)
#      29 def __init__(self, config_or_path, shell=None, **kwargs):
#      30     # `config_or_model` can be a restored `Model` object coming with
#      31     # its oun config object, or it can be a configuration object to be used
#      32     # to create a `Model` object
# ---> 33     super().__init__(BertForPreTraining, config_or_path, shell)
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\model_env.py:16, in MODEL.__init__(self, BertModel, config_or_model, shell, args)
#      13 super().__init__()
#      15 self.shell = shell
# ---> 16 model = self.model_factory(BertModel, config_or_model, args)
#      17 self.model = model.to(model.config.device)
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\model_env.py:30, in MODEL.model_factory(self, BertModel, config_or_path, args)
#      27 config = BertConfig.from_pretrained(
#      28     pretrained_model_name_or_path=path)
#      29 for k, v in config_diff.items():
# ---> 30     setattr(config, k, v)
#      31 model = BertModel.from_pretrained(
#      32         pretrained_model_name_or_path=path, config=config)
#      33 return model
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\configuration_utils.py:205, in PretrainedConfig.__setattr__(self, key, value)
#     203 if key in super().__getattribute__("attribute_map"):
#     204     key = super().__getattribute__("attribute_map")[key]
# --> 205 super().__setattr__(key, value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\configuration_utils.py:351, in PretrainedConfig.num_labels(self, num_labels)
#     348 @num_labels.setter
#     349 def num_labels(self, num_labels: int):
#     350     if not hasattr(self, "id2label") or self.id2label is None or len(self.id2label) != num_labels:
# --> 351         self.id2label = {i: f"LABEL_{i}" for i in range(num_labels)}
#     352         self.label2id = dict(zip(self.id2label.values(), self.id2label.keys()))
#
# TypeError: 'NoneType' object cannot be interpreted as an integer

# %%
def trainer():
    training_shell = RE_TRAIN(
        data_store=DATA_STORE,
        data=None,
        model=None,
    )

    # training_shell.model=PRE.MODEL
    # training_shell.data=data(path.join(
    #   DATA_STORE,
    #   'data_tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;_snd.pkl'),
    #   DEVICE)
    # training_shell.pretrained_path = path.join(
    #   DATA_STORE,
    #   'tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;/BERT_PRE_bert_half/BERT_PRE_bert_half_bst_.pt')
    # training_shell.batch_size = 256
    # training_shell.stop_thd=0.2
    # training_shell.init(DEVICE, name_prep='snd', force=True)
    # training_shell.train()
    # # project dir: /content/drive/MyDrive/workplaces/szx81/EURUSD/data_store/tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;/BERT_PRE_bert_snd
    # # project name: BERT_PRE_bert_snd
    # # training; loss trn,val:0.92,0.98; best:0.33; train:nsp,mlm:0.13,0.22; val.:nsp,mlm:0.11,0.21; ep:30; batch:43/440;

    training_shell.model=PRE.MODEL
    training_shell.data=data(path.join(
      DATA_STORE,
      'data_tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;_pred.pkl'),
      DEVICE)
    training_shell.pretrained_path = path.join(
      DATA_STORE_G,
      'tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;/BERT_PRE_bert_half/BERT_PRE_bert_half_bst_.pt')
    training_shell.batch_size = 256
    training_shell.stop_thd=0.2
    training_shell.init(DEVICE, name_prep='pred', force=True)
    training_shell.train()

    '''DEFAULTS:
    '''
trainer()
# Out:
# train data size: 112494
# validation data size: 37499
# test data size: 49997
# vocab hash: e10518ec19978398
#
# project dir: C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\tokenizer_piecewise_short;mean_len-15;seg_size-10;idx_step-1;level-4;\BERT_PRE_bert_pred
# project name: BERT_PRE_bert_pred
#
#  training; wait... ep:1; batch:20/440;
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 40
#      36     training_shell.train()
#      38     '''DEFAULTS:
#      39     '''
# ---> 40 trainer()
#
# Cell In[4], line 36, in trainer()
#      34 training_shell.stop_thd=0.2
#      35 training_shell.init(DEVICE, name_prep='pred', force=True)
# ---> 36 training_shell.train()
#      38 '''DEFAULTS:
#      39 '''
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\re_train.py:131, in ReTrain.train(self)
#     130 def train(self):
# --> 131     self.project_shell.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\project_shell.py:90, in ProjectShell.train(self)
#      88 def train(self):
#      89     if self.ok_run:
# ---> 90         self.ms.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\model_shell.py:135, in ModelShell.train(self)
#     132 print_progress('training', epochs, idx, self.train_dataloader)
#     134 self.optimizer.zero_grad()
# --> 135 loss = self.model_env(batch)
#     136 train_current.append(self.model_env.current)
#     137 train_running_loss += loss.item()
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\bert\pre\model.py:41, in MODEL.forward(self, batch)
#      40 def forward(self, batch):
# ---> 41     model_out = self.model(
#      42             output_hidden_states=True,
#      43             return_dict=True,
#      44             **batch['input']
#      45         )
#      47     prediction_logits = model_out.prediction_logits
#      48     seq_relationship_logits = model_out.seq_relationship_logits
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:1248, in BertForPreTraining.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, labels, next_sentence_label, output_attentions, output_hidden_states, return_dict)
#    1214 r"""
#    1215     labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1216         Labels for computing the masked language modeling loss. Indices should be in `[-100, 0, ...,
#    (...)
#    1244 ```
#    1245 """
#    1246 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1248 outputs = self.bert(
#    1249     input_ids,
#    1250     attention_mask=attention_mask,
#    1251     token_type_ids=token_type_ids,
#    1252     position_ids=position_ids,
#    1253     head_mask=head_mask,
#    1254     inputs_embeds=inputs_embeds,
#    1255     output_attentions=output_attentions,
#    1256     output_hidden_states=output_hidden_states,
#    1257     return_dict=return_dict,
#    1258 )
#    1260 sequence_output, pooled_output = outputs[:2]
#    1261 prediction_scores, seq_relationship_score = self.cls(sequence_output, pooled_output)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:1144, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1137 # Prepare head mask if needed
#    1138 # 1.0 in head_mask indicate we keep the head
#    1139 # attention_probs has shape bsz x n_heads x N x N
#    1140 # input head_mask has shape [num_heads] or [num_hidden_layers x num_heads]
#    1141 # and head_mask is converted to shape [num_hidden_layers x batch x num_heads x seq_length x seq_length]
#    1142 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# -> 1144 encoder_outputs = self.encoder(
#    1145     embedding_output,
#    1146     attention_mask=extended_attention_mask,
#    1147     head_mask=head_mask,
#    1148     encoder_hidden_states=encoder_hidden_states,
#    1149     encoder_attention_mask=encoder_extended_attention_mask,
#    1150     past_key_values=past_key_values,
#    1151     use_cache=use_cache,
#    1152     output_attentions=output_attentions,
#    1153     output_hidden_states=output_hidden_states,
#    1154     return_dict=return_dict,
#    1155 )
#    1156 sequence_output = encoder_outputs[0]
#    1157 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:695, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     684     layer_outputs = self._gradient_checkpointing_func(
#     685         layer_module.__call__,
#     686         hidden_states,
#    (...)
#     692         output_attentions,
#     693     )
#     694 else:
# --> 695     layer_outputs = layer_module(
#     696         hidden_states,
#     697         attention_mask,
#     698         layer_head_mask,
#     699         encoder_hidden_states,
#     700         encoder_attention_mask,
#     701         past_key_value,
#     702         output_attentions,
#     703     )
#     705 hidden_states = layer_outputs[0]
#     706 if use_cache:
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:585, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     573 def forward(
#     574     self,
#     575     hidden_states: torch.Tensor,
#    (...)
#     582 ) -> Tuple[torch.Tensor]:
#     583     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     584     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 585     self_attention_outputs = self.attention(
#     586         hidden_states,
#     587         attention_mask,
#     588         head_mask,
#     589         output_attentions=output_attentions,
#     590         past_key_value=self_attn_past_key_value,
#     591     )
#     592     attention_output = self_attention_outputs[0]
#     594     # if decoder, the last output is tuple of self-attn cache
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:515, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     505 def forward(
#     506     self,
#     507     hidden_states: torch.Tensor,
#    (...)
#     513     output_attentions: Optional[bool] = False,
#     514 ) -> Tuple[torch.Tensor]:
# --> 515     self_outputs = self.self(
#     516         hidden_states,
#     517         attention_mask,
#     518         head_mask,
#     519         encoder_hidden_states,
#     520         encoder_attention_mask,
#     521         past_key_value,
#     522         output_attentions,
#     523     )
#     524     attention_output = self.output(self_outputs[0], hidden_states)
#     525     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\transformers\models\bert\modeling_bert.py:409, in BertSdpaSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     407 else:
#     408     key_layer = self.transpose_for_scores(self.key(current_states))
# --> 409     value_layer = self.transpose_for_scores(self.value(current_states))
#     410     if past_key_value is not None and not is_cross_attention:
#     411         key_layer = torch.cat([past_key_value[0], key_layer], dim=2)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
