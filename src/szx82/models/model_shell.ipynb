# %%
from os import path
import shutil
import tempfile
from torch.utils.data import DataLoader

import szx81.core.tools as tools
from szx82.models.model_shell import ModelShell, SaveBestModel
from szx82.models.bert.re_train import Dataset
import szx82.models.bert.pre.model as PRE
from szx81.models.bert.data.mlm_nsp import MlmNspDto # fore pickling

# %%
bert_input_file=r'C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\MlmNsp_UP_(-1,),aligned-l_piecewise;mean_len-15;seg_size-10;idx_step-1;data_range-(0, 302879);\MlmNsp_UP_(-1,),aligned-l_piecewise;mean_len-15;seg_size-10;idx_step-1;data_range-(0, 302879);.pkl'
bert_input = tools.load(bert_input_file, verbose=False)
pretrained_path = path.join(
        r'C:\Users\stefa\Documents\workspaces\szx81\EURUSD\data_store\MlmNsp_UP_(-1,),aligned-l_piecewise;mean_len-15;seg_size-10;idx_step-1;data_range-(0, 302879);\BERT_PRE_UP',
        'model_bst_.pt'
)

# %%
tmpdir = tempfile.TemporaryDirectory()
_ = shutil.copytree(pretrained_path, tmpdir.name, dirs_exist_ok=True)

# %%
model_shell = ModelShell(
    train_dataloader=DataLoader(
                        Dataset(bert_input.train_data[:10000]),
                        batch_size=256,
                        ),
    val_dataloader=DataLoader(
                        Dataset(bert_input.val_data[:10000]),
                        batch_size=256,
                        ),
    ModelClass=PRE.MODEL,
    config_or_path = tmpdir.name,
)

# %%
model_shell.train()
# Out:
#  training; get loss scale... ep:0; batch:35/625;
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 model_shell.train()
#
# File G:\My Drive\workplaces\szx82\src\szx82\models\model_shell.py:140, in ModelShell.train(self)
#     137 print_progress('training', epochs, idx, self.train_dataloader)
#     139 self.optimizer.zero_grad()
# --> 140 loss = self.model_env(batch)
#     141 train_current.append(self.model_env.current)
#     142 train_running_loss.append(loss.item())
#
# File c:\Python\Python310\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# ...
